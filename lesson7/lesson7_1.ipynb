# %%
city1 = '台北'
city2 = '台中'
city3 = '高雄'

print(city1)
print(city2)
print(city3)
# Out:
# 台北
# 台中
# 高雄

# %%
# []建立list
cities = ['台北','台中','高雄']
cities
# Out:
# ['台北', '台中', '高雄']

# %%
# []建立list
cities = ['台北','台中','高雄']
print(cities)
print(cities[0])
print(cities[1])
print(cities[2])
#print(cities[3])
# Out:
# ['台北', '台中', '高雄']
# 台北
# 台中
# 高雄

# %%
greetings = ['h','e','l','l','o' ',','L','U']
greetings
# Out:
# ['h', 'e', 'l', 'l', 'o,', 'L', 'U']

# %%
"hello YU"
# Out:
# 'hello YU'

# %%
list ("hello YU")
# Out:
# ['h', 'e', 'l', 'l', 'o', ' ', 'Y', 'U']

# %%
#建立list的實體
greetings = list("hello YU!")
print(type(greetings))
print(greetings)
print(greetings[0])
print(greetings[7])
# Out:
# <class 'list'>
# ['h', 'e', 'l', 'l', 'o', ' ', 'Y', 'U', '!']
# h
# U
