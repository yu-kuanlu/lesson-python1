# %%
cities = [] #這個是空值
cities

#使用list的實體方法append()
cities.append('台北')
cities 
print(cities)
cities.append('台中')
print(cities)
cities.append('台南')
print(cities)
cities.append('高雄')
# Out:
# ['台北']
# ['台北', '台中']
# ['台北', '台中', '台南']

# %%
cities.insert(0,'基隆')
print(cities)
cities.clear()
print(cities)
# Out:
# ['基隆', '基隆', '基隆', '基隆', '台北', '台中', '台南', '高雄']
# []
