# %%
class Person:
    def __init__(self,name:str,age:int):
        self.name = name
        self.age = age

# %%
p1 = Person("YULU",35)
print(p1.name)
print(p1.age)
# Out:
# YULU
# 35

# %%
p2 = Person(age=35,name="kuanyu")
print(p2.name)
print(p2.age)
# Out:
# kuanyu
# 35
