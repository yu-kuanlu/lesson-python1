# %%
class Person:
    def __init__(self,name:str,age:int): #自訂的初始化
        self.name = name
        self.age = age

    #實體方法
    def description(self):
        print(f"我的名字叫{self.name}")
        print(f"我的age是:{self.age}")

# %%
p1 = Person(name="YUKUANLU", age=18)
p1.description()
# Out:
# 我的名字叫YUKUANLU
# 我的age是:18

# %%
# Student繼承於Person
# Person是父類別
# Student是子類別

class Student(Person):
    @classmethod
    def nickname(cls):
        print("我是class的method")

    @staticmethod
    def heroname():
        print("我是static的method")
    
    def __init__(self,name:str,age:int,chinese:int=60,english:int=60,math:int=60):
        super().__init__(name,age)
        self.__chinese = chinese
        self.__english = english
        self.__math = math

    @property
    def chinese(self)->int:
        return self.__chinese
    
    @property
    def english(self)->int:
        return self.__english
    
    @property
    def math(self)->int:
        return self.__math
    
    #覆寫(override)
    def description(self):
        super().description()
        print(f"國文:{self.chinese}")
        print(f"英文:{self.english}")
        print(f"數學:{self.math}")

# %%
s1 = Student(name="yukuanlu",age=18,math=77,english=66,chinese=88)
print(s1.chinese)
print(s1.english)
print(s1.math)
# Out:
# 88
# 66
# 77

# %%
s1 = Student(name="yukuanlu",age=18,english=86,math=92)
s1.description()
# Out:
# 我的名字叫yukuanlu
# 我的age是:18
# 國文:60
# 英文:86
# 數學:92

# %%
print(s1.chinese)
s1.description()
# Out:
# 60
# 我的名字叫yukuanlu
# 我的age是:18
# 國文:60
# 英文:86
# 數學:92

# %%
Student.nickname()
Student.heroname()
# Out:
# 我是class的method
# 我是static的method
